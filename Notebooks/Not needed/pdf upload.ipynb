# %%
###Not needed. The info of these tariffs was not applied

# %%
# !pip install pdfplumber

import pdfplumber
import pandas as pd

data = []

with pdfplumber.open(r"C:\Users\rcrds\Desktop\Ironhack\Final Project\Annex-I.pdf") as pdf:
    for page in pdf.pages:
        table = page.extract_table()
        if table:
            data.extend(table)

df_annex = pd.DataFrame(data[1:], columns=data[0])
df_annex.head()
# Out:
# ...
#    ---------------------------------------- 0.0/6.6 MB ? eta -:--:--
#    --------------- ------------------------ 2.6/6.6 MB 13.4 MB/s eta 0:00:01
#    ---------------------------------------- 6.6/6.6 MB 18.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ---------------------------------------- 3.1/3.1 MB 29.4 MB/s  0:00:00
# ...
#
#    ------------- -------------------------- 1/3 [pdfminer.six]
#    ------------- -------------------------- 1/3 [pdfminer.six]
#    -------------------------- ------------- 2/3 [pdfplumber]
#    ---------------------------------------- 3/3 [pdfplumber]
#
# ...
#                   Country Reciprocal Tariff,\nAdjusted
# 0                 Algeria                          30%
# 1                  Angola                          32%
# 2              Bangladesh                          37%
# 3  Bosnia and Herzegovina                          35%
# 4                Botswana                          37%

# %%
df_annex.to_csv(r"C:\Users\rcrds\Desktop\Ironhack\Final Project\Merged Datasets\annex1.csv", index=False)
