# %%
###This notebook has the purpose of merging different datasets using 'concat'

# %%
import pandas as pd

df_mfn1 = pd.read_csv(r"C:\Users\rcrds\Desktop\Ironhack\Final Project\Original Datasets\adb_mfn_applied_duty_23_02_2026_16_16_01.csv")
df_mfn1
# Out:
#                                           indicator  reporter_code  \
# 0      MFN_applied_duty_simple_average_in_percentage          C840
# 1      MFN_applied_duty_simple_average_in_percentage          C840
# 2      MFN_applied_duty_simple_average_in_percentage          C840
# 3      MFN_applied_duty_simple_average_in_percentage          C840
# 4      MFN_applied_duty_simple_average_in_percentage          C840
# ...                                              ...           ...
# 21994  MFN_applied_duty_simple_average_in_percentage          C840
# 21995  MFN_applied_duty_simple_average_in_percentage          C840
# 21996  MFN_applied_duty_simple_average_in_percentage          C840
# 21997  MFN_applied_duty_simple_average_in_percentage          C840
# 21998  MFN_applied_duty_simple_average_in_percentage          C840
#
#                   reporter_name  year classification_version  product_code  \
# 0      United States of America  2020                   HS17        961590
# ...

# %%
df_mfn2 = pd.read_csv(r"C:\Users\rcrds\Desktop\Ironhack\Final Project\Original Datasets\adb_mfn_applied_duty_23_02_2026_16_17_25.csv")
df_mfn2
# Out:
#                                           indicator  reporter_code  \
# 0      MFN_applied_duty_simple_average_in_percentage          C840
# 1      MFN_applied_duty_simple_average_in_percentage          C840
# 2      MFN_applied_duty_simple_average_in_percentage          C840
# 3      MFN_applied_duty_simple_average_in_percentage          C840
# 4      MFN_applied_duty_simple_average_in_percentage          C840
# ...                                              ...           ...
# 11219  MFN_applied_duty_simple_average_in_percentage          C840
# 11220  MFN_applied_duty_simple_average_in_percentage          C840
# 11221  MFN_applied_duty_simple_average_in_percentage          C840
# 11222  MFN_applied_duty_simple_average_in_percentage          C840
# 11223  MFN_applied_duty_simple_average_in_percentage          C840
#
#                   reporter_name  year classification_version  product_code  \
# 0      United States of America  2024                   HS22        960899
# ...

# %%
df_mfn = pd.concat([df_mfn1,df_mfn2])
df_mfn
# Out:
#                                           indicator  reporter_code  \
# 0      MFN_applied_duty_simple_average_in_percentage          C840
# 1      MFN_applied_duty_simple_average_in_percentage          C840
# 2      MFN_applied_duty_simple_average_in_percentage          C840
# 3      MFN_applied_duty_simple_average_in_percentage          C840
# 4      MFN_applied_duty_simple_average_in_percentage          C840
# ...                                              ...           ...
# 11219  MFN_applied_duty_simple_average_in_percentage          C840
# 11220  MFN_applied_duty_simple_average_in_percentage          C840
# 11221  MFN_applied_duty_simple_average_in_percentage          C840
# 11222  MFN_applied_duty_simple_average_in_percentage          C840
# 11223  MFN_applied_duty_simple_average_in_percentage          C840
#
#                   reporter_name  year classification_version  product_code  \
# 0      United States of America  2020                   HS17        961590
# ...

# %%
df_mfn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33223 entries, 0 to 11223
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   indicator               33223 non-null  object
#  1   reporter_code           33223 non-null  object
#  2   reporter_name           33223 non-null  object
#  3   year                    33223 non-null  int64
#  4   classification_version  33223 non-null  object
#  5   product_code            33223 non-null  int64
#  6   partner_code            33223 non-null  object
#  7   partner_name            33223 non-null  object
#  8   value                   33133 non-null  float64
#  9   source                  33223 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 2.8+ MB

# %%
df_mfn.product_code.value_counts()
# Out:
# product_code
# 20442     6
# 20742     6
# 20990     6
# 21020     6
# 30232     6
#          ..
# 854140    2
# 293138    2
# 290339    2
# 293131    2
# 999999    1
# Name: count, Length: 5758, dtype: int64

# %%
df_mfn[df_mfn["product_code"]==20442]
# Out:
#                                           indicator  reporter_code  \
# 5386   MFN_applied_duty_simple_average_in_percentage          C840
# 7201   MFN_applied_duty_simple_average_in_percentage          C840
# 13091  MFN_applied_duty_simple_average_in_percentage          C840
# 17929  MFN_applied_duty_simple_average_in_percentage          C840
# 3069   MFN_applied_duty_simple_average_in_percentage          C840
# 6961   MFN_applied_duty_simple_average_in_percentage          C840
#
#                   reporter_name  year classification_version  product_code  \
# 5386   United States of America  2020                   HS17         20442
# 7201   United States of America  2021                   HS17         20442
# 13091  United States of America  2022                   HS22         20442
# 17929  United States of America  2023                   HS22         20442
# 3069   United States of America  2024                   HS22         20442
# ...

# %%
#df_mfn.to_csv(r"C:\Users\rcrds\Desktop\Ironhack\Final Project\Merged Datasets\merged_mfn.csv")

# %%
df_imports1 = pd.read_csv(r"C:\Users\rcrds\Desktop\Ironhack\Final Project\Original Datasets\adb_imports_02_03_2026_13_06_16.csv")
df_imports1
# Out:
#        indicator  reporter_code             reporter_name  year  \
# 0         Imports          C840  United States of America  2024
# 1         Imports          C840  United States of America  2024
# 2         Imports          C840  United States of America  2024
# 3         Imports          C840  United States of America  2024
# 4         Imports          C840  United States of America  2024
# ...           ...           ...                       ...   ...
# 443928    Imports          C840  United States of America  2022
# 443929    Imports          C840  United States of America  2022
# 443930    Imports          C840  United States of America  2022
# 443931    Imports          C840  United States of America  2022
# 443932    Imports          C840  United States of America  2022
#
#        classification_version  product_code partner_code  \
# 0                        HS22        848690         C344
# 1                        HS22        848520         C376
# ...

# %%
df_imports1 = df_imports1[df_imports1["partner_name"]!="World"]

# %%
df_imports1.pivot_table(index="partner_name",columns="year",values="value", aggfunc="sum")/1000000
# Out:
# year                                       2020           2021           2022  \
# partner_name
# Afghanistan                           15.222749      21.338501      22.381071
# Albania                               45.681878      63.819962     141.652886
# Algeria                              421.753170    1744.598545    2933.187075
# Andorra                                5.372439       8.006603       9.585350
# Angola                               479.235749    1024.533542    1516.739077
# ...                                         ...            ...            ...
# Venezuela, Bolivarian Republic of    189.656450     285.514088     668.289886
# Viet Nam                           77826.637107  100531.442922  123504.555376
# Yemen                                  3.768829      10.151168      18.253561
# Zambia                                53.777420     180.374920     135.380660
# Zimbabwe                              36.709598      42.180016      86.104961
#
# ...

# %%
round(df_imports1.groupby("year")["value"].agg("sum")/1000000,2)
# Out:
# year
# 2020    2227485.83
# 2021    2696464.32
# 2022    3105319.01
# 2024    3123563.02
# Name: value, dtype: float64

# %%
#df_imports2 = pd.read_csv(r"C:\Users\rcrds\Desktop\Ironhack\Final Project\Original Datasets\adb_imports_23_02_2026_16_17_46.csv")
#df_imports2
# Out:
#        indicator  reporter_code             reporter_name  year  \
# 0         Imports          C840  United States of America  2024
# 1         Imports          C840  United States of America  2024
# 2         Imports          C840  United States of America  2024
# 3         Imports          C840  United States of America  2024
# 4         Imports          C840  United States of America  2024
# ...           ...           ...                       ...   ...
# 113299    Imports          C840  United States of America  2024
# 113300    Imports          C840  United States of America  2024
# 113301    Imports          C840  United States of America  2024
# 113302    Imports          C840  United States of America  2024
# 113303    Imports          C840  United States of America  2024
#
#        classification_version  product_code partner_code    partner_name  \
# 0                        HS22        970690         C152           Chile
# ...

# %%
df_imports = pd.concat([df_imports1,df_imports2])
df_imports
# Out:
#        indicator  reporter_code             reporter_name  year  \
# 0         Imports          C840  United States of America  2020
# 1         Imports          C840  United States of America  2020
# 2         Imports          C840  United States of America  2020
# 3         Imports          C840  United States of America  2020
# 4         Imports          C840  United States of America  2020
# ...           ...           ...                       ...   ...
# 113299    Imports          C840  United States of America  2024
# 113300    Imports          C840  United States of America  2024
# 113301    Imports          C840  United States of America  2024
# 113302    Imports          C840  United States of America  2024
# 113303    Imports          C840  United States of America  2024
#
#        classification_version  product_code partner_code      partner_name  \
# 0                        HS17        960190         C332             Haiti
# ...

# %%
df_imports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 557111 entries, 0 to 113303
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   indicator               557111 non-null  object
#  1   reporter_code           557111 non-null  object
#  2   reporter_name           557111 non-null  object
#  3   year                    557111 non-null  int64
#  4   classification_version  557111 non-null  object
#  5   product_code            557111 non-null  int64
#  6   partner_code            557111 non-null  object
#  7   partner_name            557111 non-null  object
#  8   value                   557111 non-null  float64
#  9   source                  557111 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 46.8+ MB

# %%
df_imports[(df_imports["partner_name"] == "Canada")&(df_imports["year"] == 2024)].value.sum()
# Out:
# np.float64(392463885760.7016)

# %%
#df_imports.to_csv(r"C:\Users\rcrds\Desktop\Ironhack\Final Project\Merged Datasets\merged_imports.csv")

# %%
df_exports1 = pd.read_csv(r"C:\Users\rcrds\Desktop\Ironhack\Final Project\Original Datasets\adb_exports_23_02_2026_16_16_57.csv")
df_exports1
# Out:
#        indicator  reporter_code             reporter_name  year  \
# 0         Exports          C840  United States of America  2021
# 1         Exports          C840  United States of America  2021
# 2         Exports          C840  United States of America  2021
# 3         Exports          C840  United States of America  2021
# 4         Exports          C840  United States of America  2021
# ...           ...           ...                       ...   ...
# 874313    Exports          C840  United States of America  2020
# 874314    Exports          C840  United States of America  2020
# 874315    Exports          C840  United States of America  2020
# 874316    Exports          C840  United States of America  2020
# 874317    Exports          C840  United States of America  2020
#
#        classification_version  product_code partner_code     partner_name  \
# 0                        HS17         10649         C756      Switzerland
# ...

# %%
df_exports2 = pd.read_csv(r"C:\Users\rcrds\Desktop\Ironhack\Final Project\Original Datasets\adb_exports_23_02_2026_16_18_08.csv")
df_exports2
# Out:
#        indicator  reporter_code             reporter_name  year  \
# 0         Exports          C840  United States of America  2024
# 1         Exports          C840  United States of America  2024
# 2         Exports          C840  United States of America  2024
# 3         Exports          C840  United States of America  2024
# 4         Exports          C840  United States of America  2024
# ...           ...           ...                       ...   ...
# 220113    Exports          C840  United States of America  2024
# 220114    Exports          C840  United States of America  2024
# 220115    Exports          C840  United States of America  2024
# 220116    Exports          C840  United States of America  2024
# 220117    Exports          C840  United States of America  2024
#
#        classification_version  product_code partner_code partner_name  \
# 0                        HS22        999999         C064       Bhutan
# ...

# %%
df_exports = pd.concat([df_exports1,df_exports2])
df_exports
# Out:
#        indicator  reporter_code             reporter_name  year  \
# 0         Exports          C840  United States of America  2021
# 1         Exports          C840  United States of America  2021
# 2         Exports          C840  United States of America  2021
# 3         Exports          C840  United States of America  2021
# 4         Exports          C840  United States of America  2021
# ...           ...           ...                       ...   ...
# 220113    Exports          C840  United States of America  2024
# 220114    Exports          C840  United States of America  2024
# 220115    Exports          C840  United States of America  2024
# 220116    Exports          C840  United States of America  2024
# 220117    Exports          C840  United States of America  2024
#
#        classification_version  product_code partner_code     partner_name  \
# 0                        HS17         10649         C756      Switzerland
# ...

# %%
df_exports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1094436 entries, 0 to 220117
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   indicator               1094436 non-null  object
#  1   reporter_code           1094436 non-null  object
#  2   reporter_name           1094436 non-null  object
#  3   year                    1094436 non-null  int64
#  4   classification_version  1094436 non-null  object
#  5   product_code            1094436 non-null  int64
#  6   partner_code            1094436 non-null  object
#  7   partner_name            1094436 non-null  object
#  8   value                   1094436 non-null  int64
#  9   source                  1094436 non-null  object
# dtypes: int64(3), object(7)
# memory usage: 91.8+ MB

# %%
#df_exports.to_csv(r"C:\Users\rcrds\Desktop\Ironhack\Final Project\Merged Datasets\merged_exports.csv")
